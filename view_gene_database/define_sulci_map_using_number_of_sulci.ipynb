# %% [markdown]
# Initially, we have a set of overlapping sulcal regions. For example, a sulcus named SULCUS can belong to two regions A and B. We want it to be listed only in the smallest region in terms of number of sulci. For example, if B contains 3 sulci and A contains 2 sulci, the sulcus SULCUS will be listed only in B. If two regions have the same number of sulci, it will be assigned to the region in alphabetical order.
#
# In practice, it creates a json file (region_to_sulci_using_smaller_number_of_sulci.json) in which each region contains the sulci for which this region has the smaller number of sulci.

# %%
import pandas as pd
import numpy as np
import json

# %%
json_regions = "/neurospin/dico/data/deep_folding/current/sulci_regions_champollion_V1.json"
with open(json_regions) as f:
    regions = json.load(f)

regions['brain']
# Out:
# {'S.C.-sylv._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left']},
#  'S.C.-S.Pe.C._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left'],
#   'S.Pe.C.inf._left': ['S.Pe.C.inf._left'],
#   'S.Pe.C.inter._left': ['S.Pe.C.inter._left'],
#   'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'],
#   'S.Pe.C.sup._left': ['S.Pe.C.sup._left'],
#   'S.Pe.C.median._left': ['S.Pe.C.median._left']},
#  'S.C.-S.Po.C._left': {'S.C._left': ['S.C._left'],
#   'S.C.sylvian._left': ['S.C.sylvian._left'],
#   'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'],
#   'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']},
#  'S.Pe.C._left': {'S.Pe.C.inf._left': ['S.Pe.C.inf._left'],
#   'S.Pe.C.inter._left': ['S.Pe.C.inter._left'],
#   'S.Pe.C.marginal._left': ['S.Pe.C.marginal._left'],
#   'S.Pe.C.sup._left': ['S.Pe.C.sup._left'],
#   'S.Pe.C.median._left': ['S.Pe.C.median._left']},
#  'S.Po.C._left': {'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left'],
#   'F.C.L.r.retroC.tr._left': ['F.C.L.r.retroC.tr._left']},
#  'S.F.int.-F.C.M.ant._left': {'F.C.M.ant._left': ['F.C.M.ant._left'],
#   'S.F.int._left': ['S.F.int._left']},
#  'S.F.inf.-BROCA-S.Pe.C.inf._left': {'S.F.inf._left': ['S.F.inf._left'],
#   'S.F.inf.ant._left': ['S.F.inf.ant._left'],
#   'F.C.L.r.ant._left': ['F.C.L.r.ant._left'],
#   'F.C.L.r.asc._left': ['F.C.L.r.asc._left'],
#   'F.C.L.r.diag._left': ['F.C.L.r.diag._left'],
#   'S.Pe.C.inf._left': ['S.Pe.C.inf._left']},
#  'S.T.s._left': {'S.T.s._left': ['S.T.s._left']},
#  'Sc.Cal.-S.Li._left': {'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'],
#   'S.O.p._left': ['S.O.p._left'],
#   'S.Li.ant._left': ['S.Li.ant._left'],
#   'S.Li.post._left': ['S.Li.post._left']},
#  'F.C.M.post.-S.p.C._left': {'F.C.M.post._left': ['F.C.M.post._left'],
#   'S.C.LPC._left': ['S.C.LPC._left'],
#   'S.p.C._left': ['S.p.C._left']},
#  'S.T.i.-S.O.T.lat._left': {'S.T.i.ant._left': ['S.T.i.ant._left'],
#   'S.T.i.post._left': ['S.T.i.post._left'],
#   'S.O.T.lat.ant._left': ['S.O.T.lat.ant._left'],
#   'S.O.T.lat.int._left': ['S.O.T.lat.int._left'],
#   'S.O.T.lat.med._left': ['S.O.T.lat.med._left'],
#   'S.O.T.lat.post._left': ['S.O.T.lat.post._left']},
#  'OCCIPITAL_left': {'OCCIPITAL_left': ['OCCIPITAL_left']},
#  'F.I.P.-F.I.P.Po.C.inf._left': {'F.I.P._left': ['F.I.P._left'],
#   'F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left']},
#  'S.F.inter.-S.F.sup._left': {'S.F.inter._left': ['S.F.inter._left'],
#   'S.F.sup._left': ['S.F.sup._left']},
#  'S.F.median-S.F.pol.tr.-S.F.sup._left': {'S.F.median._left': ['S.F.median._left'],
#   'S.F.polaire.tr._left': ['S.F.polaire.tr._left'],
#   'S.F.sup._left': ['S.F.sup._left']},
#  'S.Or._left': {'S.Or._left': ['S.Or._left']},
#  'S.Or.-S.Olf._left': {'S.Or._left': ['S.Or._left'],
#   'S.Olf._left': ['S.Olf._left']},
#  'F.P.O.-S.Cu.-Sc.Cal._left': {'F.P.O._left': ['F.P.O._left'],
#   'S.Pa.t._left': ['S.Pa.t._left'],
#   'S.Cu._left': ['S.Cu._left'],
#   'F.Cal.ant.-Sc.Cal._left': ['F.Cal.ant.-Sc.Cal._left'],
#   'S.O.p._left': ['S.O.p._left']},
#  'S.s.P.-S.Pa.int._left': {'S.s.P._left': ['S.s.P._left'],
#   'S.Pa.int._left': ['S.Pa.int._left']},
#  'S.T.s.br._left': {'F.I.P.r.int.1_left': ['F.I.P.r.int.1_left'],
#   'F.I.P.r.int.2_left': ['F.I.P.r.int.2_left'],
#   'S.T.s.ter.asc.ant._left': ['S.T.s.ter.asc.ant._left'],
#   'S.T.s.ter.asc.post._left': ['S.T.s.ter.asc.post._left'],
#   'S.GSM._left': ['S.GSM._left']},
#  'Lobule_parietal_sup._left': {'F.I.P._left': ['F.I.P._left'],
#   'S.Po.C.sup._left': ['S.Po.C.sup._left'],
#   'S.Pa.sup._left': ['S.Pa.sup._left']},
#  'S.F.marginal-S.F.inf.ant._left': {'S.F.marginal._left': ['S.F.marginal._left'],
#   'S.F.orbitaire._left': ['S.F.orbitaire._left'],
#   'S.F.inf.ant._left': ['S.F.inf.ant._left']},
#  'F.Coll.-S.Rh._left': {'F.Coll._left': ['F.Coll._left'],
#   'S.Rh._left': ['S.Rh._left']},
#  'S.T.i.-S.T.s.-S.T.pol._left': {'S.T.i.ant._left': ['S.T.i.ant._left'],
#   'S.T.i.post._left': ['S.T.i.post._left'],
#   'S.T.s._left': ['S.T.s._left'],
#   'S.T.pol._left': ['S.T.pol._left']},
#  'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left': {'F.C.L.p._left': ['F.C.L.p._left'],
#   'F.C.L.r.sc.ant._left': ['F.C.L.r.sc.ant._left'],
#   'F.C.L.r.sc.post._left': ['F.C.L.r.sc.post._left'],
#   'INSULA_left': ['INSULA_left'],
#   'F.C.L.a._left': ['F.C.L.a._left']},
#  'S.F.int.-S.R._left': {'S.F.int._left': ['S.F.int._left'],
#   'S.R.inf._left': ['S.R.inf._left'],
#   'S.R.sup._left': ['S.R.sup._left']},
#  'S.Call._left': {'S.Call._left': ['S.Call._left']},
#  'S.Call.-S.s.P.-S.intraCing._left': {'S.Call._left': ['S.Call._left'],
#   'S.s.P._left': ['S.s.P._left'],
#   'S.intraCing._left': ['S.intraCing._left']},
#  'S.C.-sylv._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right']},
#  'S.C.-S.Pe.C._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right'],
#   'S.Pe.C.inf._right': ['S.Pe.C.inf._right'],
#   'S.Pe.C.inter._right': ['S.Pe.C.inter._right'],
#   'S.Pe.C.marginal._right': ['S.Pe.C.marginal._right'],
#   'S.Pe.C.sup._right': ['S.Pe.C.sup._right'],
#   'S.Pe.C.median._right': ['S.Pe.C.median._right']},
#  'S.C.-S.Po.C._right': {'S.C._right': ['S.C._right'],
#   'S.C.sylvian._right': ['S.C.sylvian._right'],
#   'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right'],
#   'F.C.L.r.retroC.tr._right': ['F.C.L.r.retroC.tr._right']},
#  'S.Pe.C._right': {'S.Pe.C.inf._right': ['S.Pe.C.inf._right'],
#   'S.Pe.C.inter._right': ['S.Pe.C.inter._right'],
#   'S.Pe.C.marginal._right': ['S.Pe.C.marginal._right'],
#   'S.Pe.C.sup._right': ['S.Pe.C.sup._right'],
#   'S.Pe.C.median._right': ['S.Pe.C.median._right']},
#  'S.Po.C._right': {'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right'],
#   'F.C.L.r.retroC.tr._right': ['F.C.L.r.retroC.tr._right']},
#  'S.F.int.-F.C.M.ant._right': {'F.C.M.ant._right': ['F.C.M.ant._right'],
#   'S.F.int._right': ['S.F.int._right']},
#  'S.F.inf.-BROCA-S.Pe.C.inf._right': {'S.F.inf._right': ['S.F.inf._right'],
#   'S.F.inf.ant._right': ['S.F.inf.ant._right'],
#   'F.C.L.r.ant._right': ['F.C.L.r.ant._right'],
#   'F.C.L.r.asc._right': ['F.C.L.r.asc._right'],
#   'F.C.L.r.diag._right': ['F.C.L.r.diag._right'],
#   'S.Pe.C.inf._right': ['S.Pe.C.inf._right']},
#  'S.T.s._right': {'S.T.s._right': ['S.T.s._right']},
#  'Sc.Cal.-S.Li._right': {'F.Cal.ant.-Sc.Cal._right': ['F.Cal.ant.-Sc.Cal._right'],
#   'S.O.p._right': ['S.O.p._right'],
#   'S.Li.ant._right': ['S.Li.ant._right'],
#   'S.Li.post._right': ['S.Li.post._right']},
#  'F.C.M.post.-S.p.C._right': {'F.C.M.post._right': ['F.C.M.post._right'],
#   'S.C.LPC._right': ['S.C.LPC._right'],
#   'S.p.C._right': ['S.p.C._right']},
#  'S.T.i.-S.O.T.lat._right': {'S.T.i.ant._right': ['S.T.i.ant._right'],
#   'S.T.i.post._right': ['S.T.i.post._right'],
#   'S.O.T.lat.ant._right': ['S.O.T.lat.ant._right'],
#   'S.O.T.lat.int._right': ['S.O.T.lat.int._right'],
#   'S.O.T.lat.med._right': ['S.O.T.lat.med._right'],
#   'S.O.T.lat.post._right': ['S.O.T.lat.post._right']},
#  'OCCIPITAL_right': {'OCCIPITAL_right': ['OCCIPITAL_right']},
#  'F.I.P.-F.I.P.Po.C.inf._right': {'F.I.P._right': ['F.I.P._right'],
#   'F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right']},
#  'S.F.inter.-S.F.sup._right': {'S.F.inter._right': ['S.F.inter._right'],
#   'S.F.sup._right': ['S.F.sup._right']},
#  'S.F.median-S.F.pol.tr.-S.F.sup._right': {'S.F.median._right': ['S.F.median._right'],
#   'S.F.polaire.tr._right': ['S.F.polaire.tr._right'],
#   'S.F.sup._right': ['S.F.sup._right']},
#  'S.Or._right': {'S.Or._right': ['S.Or._right']},
#  'S.Or.-S.Olf._right': {'S.Or._right': ['S.Or._right'],
#   'S.Olf._right': ['S.Olf._right']},
#  'F.P.O.-S.Cu.-Sc.Cal._right': {'F.P.O._right': ['F.P.O._right'],
#   'S.Pa.t._right': ['S.Pa.t._right'],
#   'S.Cu._right': ['S.Cu._right'],
#   'F.Cal.ant.-Sc.Cal._right': ['F.Cal.ant.-Sc.Cal._right'],
#   'S.O.p._right': ['S.O.p._right']},
#  'S.s.P.-S.Pa.int._right': {'S.s.P._right': ['S.s.P._right'],
#   'S.Pa.int._right': ['S.Pa.int._right']},
#  'S.T.s.br._right': {'F.I.P.r.int.1_right': ['F.I.P.r.int.1_right'],
#   'F.I.P.r.int.2_right': ['F.I.P.r.int.2_right'],
#   'S.T.s.ter.asc.ant._right': ['S.T.s.ter.asc.ant._right'],
#   'S.T.s.ter.asc.post._right': ['S.T.s.ter.asc.post._right'],
#   'S.GSM._right': ['S.GSM._right']},
#  'Lobule_parietal_sup._right': {'F.I.P._right': ['F.I.P._right'],
#   'S.Po.C.sup._right': ['S.Po.C.sup._right'],
#   'S.Pa.sup._right': ['S.Pa.sup._right']},
#  'S.F.marginal-S.F.inf.ant._right': {'S.F.marginal._right': ['S.F.marginal._right'],
#   'S.F.orbitaire._right': ['S.F.orbitaire._right'],
#   'S.F.inf.ant._right': ['S.F.inf.ant._right']},
#  'F.Coll.-S.Rh._right': {'F.Coll._right': ['F.Coll._right'],
#   'S.Rh._right': ['S.Rh._right']},
#  'S.T.i.-S.T.s.-S.T.pol._right': {'S.T.i.ant._right': ['S.T.i.ant._right'],
#   'S.T.i.post._right': ['S.T.i.post._right'],
#   'S.T.s._right': ['S.T.s._right'],
#   'S.T.pol._right': ['S.T.pol._right']},
#  'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right': {'F.C.L.p._right': ['F.C.L.p._right'],
#   'F.C.L.r.sc.ant._right': ['F.C.L.r.sc.ant._right'],
#   'F.C.L.r.sc.post._right': ['F.C.L.r.sc.post._right'],
#   'INSULA_right': ['INSULA_right'],
#   'F.C.L.a._right': ['F.C.L.a._right']},
#  'S.F.int.-S.R._right': {'S.F.int._right': ['S.F.int._right'],
#   'S.R.inf._right': ['S.R.inf._right'],
#   'S.R.sup._right': ['S.R.sup._right']},
#  'S.Call._right': {'S.Call._right': ['S.Call._right']},
#  'S.Call.-S.s.P.-S.intraCing._right': {'S.Call._right': ['S.Call._right'],
#   'S.s.P._right': ['S.s.P._right'],
#   'S.intraCing._right': ['S.intraCing._right']}}

# %%
def get_sulci(region):
    list_sulci = list(regions['brain'][f"{region}"].keys())
    return list_sulci

# %%
regions_list = list(regions['brain'].keys())
sulci_list = [get_sulci(region) for region in regions_list]


map_table = pd.DataFrame({
    'Region': regions_list,
    'Sulci': sulci_list
})

map_table['region_size'] = map_table["Sulci"].apply(lambda x: len(x))
map_table
# Out:
#                                     Region  \
# 0                          S.C.-sylv._left
# 1                        S.C.-S.Pe.C._left
# 2                        S.C.-S.Po.C._left
# 3                             S.Pe.C._left
# 4                             S.Po.C._left
# 5                 S.F.int.-F.C.M.ant._left
# 6          S.F.inf.-BROCA-S.Pe.C.inf._left
# 7                              S.T.s._left
# 8                       Sc.Cal.-S.Li._left
# 9                  F.C.M.post.-S.p.C._left
# 10                  S.T.i.-S.O.T.lat._left
# 11                          OCCIPITAL_left
# 12             F.I.P.-F.I.P.Po.C.inf._left
# 13                S.F.inter.-S.F.sup._left
# 14    S.F.median-S.F.pol.tr.-S.F.sup._left
# 15                              S.Or._left
# 16                       S.Or.-S.Olf._left
# 17               F.P.O.-S.Cu.-Sc.Cal._left
# 18                   S.s.P.-S.Pa.int._left
# 19                          S.T.s.br._left
# 20               Lobule_parietal_sup._left
# 21          S.F.marginal-S.F.inf.ant._left
# 22                      F.Coll.-S.Rh._left
# 23             S.T.i.-S.T.s.-S.T.pol._left
# 24   F.C.L.p.-subsc.-F.C.L.a.-INSULA._left
# 25                      S.F.int.-S.R._left
# 26                            S.Call._left
# 27        S.Call.-S.s.P.-S.intraCing._left
# 28                        S.C.-sylv._right
# 29                      S.C.-S.Pe.C._right
# 30                      S.C.-S.Po.C._right
# 31                           S.Pe.C._right
# 32                           S.Po.C._right
# 33               S.F.int.-F.C.M.ant._right
# 34        S.F.inf.-BROCA-S.Pe.C.inf._right
# 35                            S.T.s._right
# 36                     Sc.Cal.-S.Li._right
# 37                F.C.M.post.-S.p.C._right
# 38                 S.T.i.-S.O.T.lat._right
# 39                         OCCIPITAL_right
# 40            F.I.P.-F.I.P.Po.C.inf._right
# 41               S.F.inter.-S.F.sup._right
# 42   S.F.median-S.F.pol.tr.-S.F.sup._right
# 43                             S.Or._right
# 44                      S.Or.-S.Olf._right
# 45              F.P.O.-S.Cu.-Sc.Cal._right
# 46                  S.s.P.-S.Pa.int._right
# 47                         S.T.s.br._right
# 48              Lobule_parietal_sup._right
# 49         S.F.marginal-S.F.inf.ant._right
# 50                     F.Coll.-S.Rh._right
# 51            S.T.i.-S.T.s.-S.T.pol._right
# 52  F.C.L.p.-subsc.-F.C.L.a.-INSULA._right
# 53                     S.F.int.-S.R._right
# 54                           S.Call._right
# 55       S.Call.-S.s.P.-S.intraCing._right
#
#                                                 Sulci  region_size
# 0                      [S.C._left, S.C.sylvian._left]            2
# 1   [S.C._left, S.C.sylvian._left, S.Pe.C.inf._lef...            7
# 2   [S.C._left, S.C.sylvian._left, S.Po.C.sup._lef...            5
# 3   [S.Pe.C.inf._left, S.Pe.C.inter._left, S.Pe.C....            5
# 4   [S.Po.C.sup._left, F.I.P.Po.C.inf._left, F.C.L...            3
# 5                    [F.C.M.ant._left, S.F.int._left]            2
# 6   [S.F.inf._left, S.F.inf.ant._left, F.C.L.r.ant...            6
# 7                                       [S.T.s._left]            1
# 8   [F.Cal.ant.-Sc.Cal._left, S.O.p._left, S.Li.an...            4
# 9      [F.C.M.post._left, S.C.LPC._left, S.p.C._left]            3
# 10  [S.T.i.ant._left, S.T.i.post._left, S.O.T.lat....            6
# 11                                   [OCCIPITAL_left]            1
# 12                [F.I.P._left, F.I.P.Po.C.inf._left]            2
# 13                   [S.F.inter._left, S.F.sup._left]            2
# 14  [S.F.median._left, S.F.polaire.tr._left, S.F.s...            3
# 15                                       [S.Or._left]            1
# 16                          [S.Or._left, S.Olf._left]            2
# 17  [F.P.O._left, S.Pa.t._left, S.Cu._left, F.Cal....            5
# 18                      [S.s.P._left, S.Pa.int._left]            2
# 19  [F.I.P.r.int.1_left, F.I.P.r.int.2_left, S.T.s...            5
# 20    [F.I.P._left, S.Po.C.sup._left, S.Pa.sup._left]            3
# 21  [S.F.marginal._left, S.F.orbitaire._left, S.F....            3
# 22                         [F.Coll._left, S.Rh._left]            2
# 23  [S.T.i.ant._left, S.T.i.post._left, S.T.s._lef...            4
# 24  [F.C.L.p._left, F.C.L.r.sc.ant._left, F.C.L.r....            5
# 25      [S.F.int._left, S.R.inf._left, S.R.sup._left]            3
# 26                                     [S.Call._left]            1
# 27     [S.Call._left, S.s.P._left, S.intraCing._left]            3
# 28                   [S.C._right, S.C.sylvian._right]            2
# 29  [S.C._right, S.C.sylvian._right, S.Pe.C.inf._r...            7
# 30  [S.C._right, S.C.sylvian._right, S.Po.C.sup._r...            5
# 31  [S.Pe.C.inf._right, S.Pe.C.inter._right, S.Pe....            5
# 32  [S.Po.C.sup._right, F.I.P.Po.C.inf._right, F.C...            3
# 33                 [F.C.M.ant._right, S.F.int._right]            2
# 34  [S.F.inf._right, S.F.inf.ant._right, F.C.L.r.a...            6
# 35                                     [S.T.s._right]            1
# 36  [F.Cal.ant.-Sc.Cal._right, S.O.p._right, S.Li....            4
# 37  [F.C.M.post._right, S.C.LPC._right, S.p.C._right]            3
# 38  [S.T.i.ant._right, S.T.i.post._right, S.O.T.la...            6
# 39                                  [OCCIPITAL_right]            1
# 40              [F.I.P._right, F.I.P.Po.C.inf._right]            2
# 41                 [S.F.inter._right, S.F.sup._right]            2
# 42  [S.F.median._right, S.F.polaire.tr._right, S.F...            3
# 43                                      [S.Or._right]            1
# 44                        [S.Or._right, S.Olf._right]            2
# 45  [F.P.O._right, S.Pa.t._right, S.Cu._right, F.C...            5
# 46                    [S.s.P._right, S.Pa.int._right]            2
# 47  [F.I.P.r.int.1_right, F.I.P.r.int.2_right, S.T...            5
# 48  [F.I.P._right, S.Po.C.sup._right, S.Pa.sup._ri...            3
# 49  [S.F.marginal._right, S.F.orbitaire._right, S....            3
# 50                       [F.Coll._right, S.Rh._right]            2
# 51  [S.T.i.ant._right, S.T.i.post._right, S.T.s._r...            4
# 52  [F.C.L.p._right, F.C.L.r.sc.ant._right, F.C.L....            5
# 53   [S.F.int._right, S.R.inf._right, S.R.sup._right]            3
# 54                                    [S.Call._right]            1
# 55  [S.Call._right, S.s.P._right, S.intraCing._right]            3

# %%
map_table_exploded = map_table.explode("Sulci").copy()
map_table_exploded = map_table_exploded[~map_table_exploded['Region'].str.contains('CINGULATE', na=False)]
map_table_exploded
# Out:
#                                Region               Sulci  region_size
# 0                     S.C.-sylv._left           S.C._left            2
# 0                     S.C.-sylv._left   S.C.sylvian._left            2
# 1                   S.C.-S.Pe.C._left           S.C._left            7
# 1                   S.C.-S.Pe.C._left   S.C.sylvian._left            7
# 1                   S.C.-S.Pe.C._left    S.Pe.C.inf._left            7
# ..                                ...                 ...          ...
# 53                S.F.int.-S.R._right      S.R.sup._right            3
# 54                      S.Call._right       S.Call._right            1
# 55  S.Call.-S.s.P.-S.intraCing._right       S.Call._right            3
# 55  S.Call.-S.s.P.-S.intraCing._right        S.s.P._right            3
# 55  S.Call.-S.s.P.-S.intraCing._right  S.intraCing._right            3
#
# [182 rows x 3 columns]

# %%
(map_table_exploded.sort_values(by=['Sulci', 'region_size'])).sort_values(by="region_size", ascending=False)
# Out:
#                 Region                 Sulci  region_size
# 29  S.C.-S.Pe.C._right   S.Pe.C.inter._right            7
# 1    S.C.-S.Pe.C._left    S.Pe.C.inter._left            7
# 29  S.C.-S.Pe.C._right     S.Pe.C.sup._right            7
# 1    S.C.-S.Pe.C._left      S.Pe.C.sup._left            7
# 29  S.C.-S.Pe.C._right  S.Pe.C.median._right            7
# ..                 ...                   ...          ...
# 15          S.Or._left            S.Or._left            1
# 43         S.Or._right           S.Or._right            1
# 26        S.Call._left          S.Call._left            1
# 7          S.T.s._left           S.T.s._left            1
# 35        S.T.s._right          S.T.s._right            1
#
# [182 rows x 3 columns]

# %%
df_sulci = map_table_exploded.sort_values(by=['Sulci', 'region_size'])\
                             .drop_duplicates(subset='Sulci', keep='first')\
                             .loc[:, ['Region', 'Sulci', 'region_size']]\
                             .reset_index(drop=True)
df_sulci
# Out:
#                                      Region               Sulci  region_size
# 0     F.C.L.p.-subsc.-F.C.L.a.-INSULA._left       F.C.L.a._left            5
# 1    F.C.L.p.-subsc.-F.C.L.a.-INSULA._right      F.C.L.a._right            5
# 2     F.C.L.p.-subsc.-F.C.L.a.-INSULA._left       F.C.L.p._left            5
# 3    F.C.L.p.-subsc.-F.C.L.a.-INSULA._right      F.C.L.p._right            5
# 4           S.F.inf.-BROCA-S.Pe.C.inf._left   F.C.L.r.ant._left            6
# ..                                      ...                 ...          ...
# 123       S.Call.-S.s.P.-S.intraCing._right  S.intraCing._right            3
# 124                 F.C.M.post.-S.p.C._left         S.p.C._left            3
# 125                F.C.M.post.-S.p.C._right        S.p.C._right            3
# 126                   S.s.P.-S.Pa.int._left         S.s.P._left            2
# 127                  S.s.P.-S.Pa.int._right        S.s.P._right            2
#
# [128 rows x 3 columns]

# %%
sulcus_to_region = dict(zip(df_sulci['Sulci'], df_sulci['Region']))
sulcus_to_region
# Out:
# {'F.C.L.a._left': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left',
#  'F.C.L.a._right': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right',
#  'F.C.L.p._left': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left',
#  'F.C.L.p._right': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right',
#  'F.C.L.r.ant._left': 'S.F.inf.-BROCA-S.Pe.C.inf._left',
#  'F.C.L.r.ant._right': 'S.F.inf.-BROCA-S.Pe.C.inf._right',
#  'F.C.L.r.asc._left': 'S.F.inf.-BROCA-S.Pe.C.inf._left',
#  'F.C.L.r.asc._right': 'S.F.inf.-BROCA-S.Pe.C.inf._right',
#  'F.C.L.r.diag._left': 'S.F.inf.-BROCA-S.Pe.C.inf._left',
#  'F.C.L.r.diag._right': 'S.F.inf.-BROCA-S.Pe.C.inf._right',
#  'F.C.L.r.retroC.tr._left': 'S.Po.C._left',
#  'F.C.L.r.retroC.tr._right': 'S.Po.C._right',
#  'F.C.L.r.sc.ant._left': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left',
#  'F.C.L.r.sc.ant._right': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right',
#  'F.C.L.r.sc.post._left': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left',
#  'F.C.L.r.sc.post._right': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right',
#  'F.C.M.ant._left': 'S.F.int.-F.C.M.ant._left',
#  'F.C.M.ant._right': 'S.F.int.-F.C.M.ant._right',
#  'F.C.M.post._left': 'F.C.M.post.-S.p.C._left',
#  'F.C.M.post._right': 'F.C.M.post.-S.p.C._right',
#  'F.Cal.ant.-Sc.Cal._left': 'Sc.Cal.-S.Li._left',
#  'F.Cal.ant.-Sc.Cal._right': 'Sc.Cal.-S.Li._right',
#  'F.Coll._left': 'F.Coll.-S.Rh._left',
#  'F.Coll._right': 'F.Coll.-S.Rh._right',
#  'F.I.P.Po.C.inf._left': 'F.I.P.-F.I.P.Po.C.inf._left',
#  'F.I.P.Po.C.inf._right': 'F.I.P.-F.I.P.Po.C.inf._right',
#  'F.I.P._left': 'F.I.P.-F.I.P.Po.C.inf._left',
#  'F.I.P._right': 'F.I.P.-F.I.P.Po.C.inf._right',
#  'F.I.P.r.int.1_left': 'S.T.s.br._left',
#  'F.I.P.r.int.1_right': 'S.T.s.br._right',
#  'F.I.P.r.int.2_left': 'S.T.s.br._left',
#  'F.I.P.r.int.2_right': 'S.T.s.br._right',
#  'F.P.O._left': 'F.P.O.-S.Cu.-Sc.Cal._left',
#  'F.P.O._right': 'F.P.O.-S.Cu.-Sc.Cal._right',
#  'INSULA_left': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left',
#  'INSULA_right': 'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right',
#  'OCCIPITAL_left': 'OCCIPITAL_left',
#  'OCCIPITAL_right': 'OCCIPITAL_right',
#  'S.C.LPC._left': 'F.C.M.post.-S.p.C._left',
#  'S.C.LPC._right': 'F.C.M.post.-S.p.C._right',
#  'S.C._left': 'S.C.-sylv._left',
#  'S.C._right': 'S.C.-sylv._right',
#  'S.C.sylvian._left': 'S.C.-sylv._left',
#  'S.C.sylvian._right': 'S.C.-sylv._right',
#  'S.Call._left': 'S.Call._left',
#  'S.Call._right': 'S.Call._right',
#  'S.Cu._left': 'F.P.O.-S.Cu.-Sc.Cal._left',
#  'S.Cu._right': 'F.P.O.-S.Cu.-Sc.Cal._right',
#  'S.F.inf._left': 'S.F.inf.-BROCA-S.Pe.C.inf._left',
#  'S.F.inf._right': 'S.F.inf.-BROCA-S.Pe.C.inf._right',
#  'S.F.inf.ant._left': 'S.F.marginal-S.F.inf.ant._left',
#  'S.F.inf.ant._right': 'S.F.marginal-S.F.inf.ant._right',
#  'S.F.int._left': 'S.F.int.-F.C.M.ant._left',
#  'S.F.int._right': 'S.F.int.-F.C.M.ant._right',
#  'S.F.inter._left': 'S.F.inter.-S.F.sup._left',
#  'S.F.inter._right': 'S.F.inter.-S.F.sup._right',
#  'S.F.marginal._left': 'S.F.marginal-S.F.inf.ant._left',
#  'S.F.marginal._right': 'S.F.marginal-S.F.inf.ant._right',
#  'S.F.median._left': 'S.F.median-S.F.pol.tr.-S.F.sup._left',
#  'S.F.median._right': 'S.F.median-S.F.pol.tr.-S.F.sup._right',
#  'S.F.orbitaire._left': 'S.F.marginal-S.F.inf.ant._left',
#  'S.F.orbitaire._right': 'S.F.marginal-S.F.inf.ant._right',
#  'S.F.polaire.tr._left': 'S.F.median-S.F.pol.tr.-S.F.sup._left',
#  'S.F.polaire.tr._right': 'S.F.median-S.F.pol.tr.-S.F.sup._right',
#  'S.F.sup._left': 'S.F.inter.-S.F.sup._left',
#  'S.F.sup._right': 'S.F.inter.-S.F.sup._right',
#  'S.GSM._left': 'S.T.s.br._left',
#  'S.GSM._right': 'S.T.s.br._right',
#  'S.Li.ant._left': 'Sc.Cal.-S.Li._left',
#  'S.Li.ant._right': 'Sc.Cal.-S.Li._right',
#  'S.Li.post._left': 'Sc.Cal.-S.Li._left',
#  'S.Li.post._right': 'Sc.Cal.-S.Li._right',
#  'S.O.T.lat.ant._left': 'S.T.i.-S.O.T.lat._left',
#  'S.O.T.lat.ant._right': 'S.T.i.-S.O.T.lat._right',
#  'S.O.T.lat.int._left': 'S.T.i.-S.O.T.lat._left',
#  'S.O.T.lat.int._right': 'S.T.i.-S.O.T.lat._right',
#  'S.O.T.lat.med._left': 'S.T.i.-S.O.T.lat._left',
#  'S.O.T.lat.med._right': 'S.T.i.-S.O.T.lat._right',
#  'S.O.T.lat.post._left': 'S.T.i.-S.O.T.lat._left',
#  'S.O.T.lat.post._right': 'S.T.i.-S.O.T.lat._right',
#  'S.O.p._left': 'Sc.Cal.-S.Li._left',
#  'S.O.p._right': 'Sc.Cal.-S.Li._right',
#  'S.Olf._left': 'S.Or.-S.Olf._left',
#  'S.Olf._right': 'S.Or.-S.Olf._right',
#  'S.Or._left': 'S.Or._left',
#  'S.Or._right': 'S.Or._right',
#  'S.Pa.int._left': 'S.s.P.-S.Pa.int._left',
#  'S.Pa.int._right': 'S.s.P.-S.Pa.int._right',
#  'S.Pa.sup._left': 'Lobule_parietal_sup._left',
#  'S.Pa.sup._right': 'Lobule_parietal_sup._right',
#  'S.Pa.t._left': 'F.P.O.-S.Cu.-Sc.Cal._left',
#  'S.Pa.t._right': 'F.P.O.-S.Cu.-Sc.Cal._right',
#  'S.Pe.C.inf._left': 'S.Pe.C._left',
#  'S.Pe.C.inf._right': 'S.Pe.C._right',
#  'S.Pe.C.inter._left': 'S.Pe.C._left',
#  'S.Pe.C.inter._right': 'S.Pe.C._right',
#  'S.Pe.C.marginal._left': 'S.Pe.C._left',
#  'S.Pe.C.marginal._right': 'S.Pe.C._right',
#  'S.Pe.C.median._left': 'S.Pe.C._left',
#  'S.Pe.C.median._right': 'S.Pe.C._right',
#  'S.Pe.C.sup._left': 'S.Pe.C._left',
#  'S.Pe.C.sup._right': 'S.Pe.C._right',
#  'S.Po.C.sup._left': 'S.Po.C._left',
#  'S.Po.C.sup._right': 'S.Po.C._right',
#  'S.R.inf._left': 'S.F.int.-S.R._left',
#  'S.R.inf._right': 'S.F.int.-S.R._right',
#  'S.R.sup._left': 'S.F.int.-S.R._left',
#  'S.R.sup._right': 'S.F.int.-S.R._right',
#  'S.Rh._left': 'F.Coll.-S.Rh._left',
#  'S.Rh._right': 'F.Coll.-S.Rh._right',
#  'S.T.i.ant._left': 'S.T.i.-S.T.s.-S.T.pol._left',
#  'S.T.i.ant._right': 'S.T.i.-S.T.s.-S.T.pol._right',
#  'S.T.i.post._left': 'S.T.i.-S.T.s.-S.T.pol._left',
#  'S.T.i.post._right': 'S.T.i.-S.T.s.-S.T.pol._right',
#  'S.T.pol._left': 'S.T.i.-S.T.s.-S.T.pol._left',
#  'S.T.pol._right': 'S.T.i.-S.T.s.-S.T.pol._right',
#  'S.T.s._left': 'S.T.s._left',
#  'S.T.s._right': 'S.T.s._right',
#  'S.T.s.ter.asc.ant._left': 'S.T.s.br._left',
#  'S.T.s.ter.asc.ant._right': 'S.T.s.br._right',
#  'S.T.s.ter.asc.post._left': 'S.T.s.br._left',
#  'S.T.s.ter.asc.post._right': 'S.T.s.br._right',
#  'S.intraCing._left': 'S.Call.-S.s.P.-S.intraCing._left',
#  'S.intraCing._right': 'S.Call.-S.s.P.-S.intraCing._right',
#  'S.p.C._left': 'F.C.M.post.-S.p.C._left',
#  'S.p.C._right': 'F.C.M.post.-S.p.C._right',
#  'S.s.P._left': 'S.s.P.-S.Pa.int._left',
#  'S.s.P._right': 'S.s.P.-S.Pa.int._right'}

# %%
from collections import defaultdict

region_to_sulci = defaultdict(list)
for sulcus, region in sulcus_to_region.items():
    region_to_sulci[region].append(sulcus)

# %%
region_to_sulci
# Out:
# defaultdict(list,
#             {'F.C.L.p.-subsc.-F.C.L.a.-INSULA._left': ['F.C.L.a._left',
#               'F.C.L.p._left',
#               'F.C.L.r.sc.ant._left',
#               'F.C.L.r.sc.post._left',
#               'INSULA_left'],
#              'F.C.L.p.-subsc.-F.C.L.a.-INSULA._right': ['F.C.L.a._right',
#               'F.C.L.p._right',
#               'F.C.L.r.sc.ant._right',
#               'F.C.L.r.sc.post._right',
#               'INSULA_right'],
#              'S.F.inf.-BROCA-S.Pe.C.inf._left': ['F.C.L.r.ant._left',
#               'F.C.L.r.asc._left',
#               'F.C.L.r.diag._left',
#               'S.F.inf._left'],
#              'S.F.inf.-BROCA-S.Pe.C.inf._right': ['F.C.L.r.ant._right',
#               'F.C.L.r.asc._right',
#               'F.C.L.r.diag._right',
#               'S.F.inf._right'],
#              'S.Po.C._left': ['F.C.L.r.retroC.tr._left', 'S.Po.C.sup._left'],
#              'S.Po.C._right': ['F.C.L.r.retroC.tr._right',
#               'S.Po.C.sup._right'],
#              'S.F.int.-F.C.M.ant._left': ['F.C.M.ant._left', 'S.F.int._left'],
#              'S.F.int.-F.C.M.ant._right': ['F.C.M.ant._right',
#               'S.F.int._right'],
#              'F.C.M.post.-S.p.C._left': ['F.C.M.post._left',
#               'S.C.LPC._left',
#               'S.p.C._left'],
#              'F.C.M.post.-S.p.C._right': ['F.C.M.post._right',
#               'S.C.LPC._right',
#               'S.p.C._right'],
#              'Sc.Cal.-S.Li._left': ['F.Cal.ant.-Sc.Cal._left',
#               'S.Li.ant._left',
#               'S.Li.post._left',
#               'S.O.p._left'],
#              'Sc.Cal.-S.Li._right': ['F.Cal.ant.-Sc.Cal._right',
#               'S.Li.ant._right',
#               'S.Li.post._right',
#               'S.O.p._right'],
#              'F.Coll.-S.Rh._left': ['F.Coll._left', 'S.Rh._left'],
#              'F.Coll.-S.Rh._right': ['F.Coll._right', 'S.Rh._right'],
#              'F.I.P.-F.I.P.Po.C.inf._left': ['F.I.P.Po.C.inf._left',
#               'F.I.P._left'],
#              'F.I.P.-F.I.P.Po.C.inf._right': ['F.I.P.Po.C.inf._right',
#               'F.I.P._right'],
#              'S.T.s.br._left': ['F.I.P.r.int.1_left',
#               'F.I.P.r.int.2_left',
#               'S.GSM._left',
#               'S.T.s.ter.asc.ant._left',
#               'S.T.s.ter.asc.post._left'],
#              'S.T.s.br._right': ['F.I.P.r.int.1_right',
#               'F.I.P.r.int.2_right',
#               'S.GSM._right',
#               'S.T.s.ter.asc.ant._right',
#               'S.T.s.ter.asc.post._right'],
#              'F.P.O.-S.Cu.-Sc.Cal._left': ['F.P.O._left',
#               'S.Cu._left',
#               'S.Pa.t._left'],
#              'F.P.O.-S.Cu.-Sc.Cal._right': ['F.P.O._right',
#               'S.Cu._right',
#               'S.Pa.t._right'],
#              'OCCIPITAL_left': ['OCCIPITAL_left'],
#              'OCCIPITAL_right': ['OCCIPITAL_right'],
#              'S.C.-sylv._left': ['S.C._left', 'S.C.sylvian._left'],
#              'S.C.-sylv._right': ['S.C._right', 'S.C.sylvian._right'],
#              'S.Call._left': ['S.Call._left'],
#              'S.Call._right': ['S.Call._right'],
#              'S.F.marginal-S.F.inf.ant._left': ['S.F.inf.ant._left',
#               'S.F.marginal._left',
#               'S.F.orbitaire._left'],
#              'S.F.marginal-S.F.inf.ant._right': ['S.F.inf.ant._right',
#               'S.F.marginal._right',
#               'S.F.orbitaire._right'],
#              'S.F.inter.-S.F.sup._left': ['S.F.inter._left', 'S.F.sup._left'],
#              'S.F.inter.-S.F.sup._right': ['S.F.inter._right',
#               'S.F.sup._right'],
#              'S.F.median-S.F.pol.tr.-S.F.sup._left': ['S.F.median._left',
#               'S.F.polaire.tr._left'],
#              'S.F.median-S.F.pol.tr.-S.F.sup._right': ['S.F.median._right',
#               'S.F.polaire.tr._right'],
#              'S.T.i.-S.O.T.lat._left': ['S.O.T.lat.ant._left',
#               'S.O.T.lat.int._left',
#               'S.O.T.lat.med._left',
#               'S.O.T.lat.post._left'],
#              'S.T.i.-S.O.T.lat._right': ['S.O.T.lat.ant._right',
#               'S.O.T.lat.int._right',
#               'S.O.T.lat.med._right',
#               'S.O.T.lat.post._right'],
#              'S.Or.-S.Olf._left': ['S.Olf._left'],
#              'S.Or.-S.Olf._right': ['S.Olf._right'],
#              'S.Or._left': ['S.Or._left'],
#              'S.Or._right': ['S.Or._right'],
#              'S.s.P.-S.Pa.int._left': ['S.Pa.int._left', 'S.s.P._left'],
#              'S.s.P.-S.Pa.int._right': ['S.Pa.int._right', 'S.s.P._right'],
#              'Lobule_parietal_sup._left': ['S.Pa.sup._left'],
#              'Lobule_parietal_sup._right': ['S.Pa.sup._right'],
#              'S.Pe.C._left': ['S.Pe.C.inf._left',
#               'S.Pe.C.inter._left',
#               'S.Pe.C.marginal._left',
#               'S.Pe.C.median._left',
#               'S.Pe.C.sup._left'],
#              'S.Pe.C._right': ['S.Pe.C.inf._right',
#               'S.Pe.C.inter._right',
#               'S.Pe.C.marginal._right',
#               'S.Pe.C.median._right',
#               'S.Pe.C.sup._right'],
#              'S.F.int.-S.R._left': ['S.R.inf._left', 'S.R.sup._left'],
#              'S.F.int.-S.R._right': ['S.R.inf._right', 'S.R.sup._right'],
#              'S.T.i.-S.T.s.-S.T.pol._left': ['S.T.i.ant._left',
#               'S.T.i.post._left',
#               'S.T.pol._left'],
#              'S.T.i.-S.T.s.-S.T.pol._right': ['S.T.i.ant._right',
#               'S.T.i.post._right',
#               'S.T.pol._right'],
#              'S.T.s._left': ['S.T.s._left'],
#              'S.T.s._right': ['S.T.s._right'],
#              'S.Call.-S.s.P.-S.intraCing._left': ['S.intraCing._left'],
#              'S.Call.-S.s.P.-S.intraCing._right': ['S.intraCing._right']})

# %%
with open("region_to_sulci_using_smaller_number_of_sulci.json", "w") as f:
    json.dump(region_to_sulci, f, indent=4)
